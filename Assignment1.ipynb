# %%
import numpy as np
import pandas as pd

# %%
newdf = pd.DataFrame(np.random.rand(4,4),index = np.arange(4))

# %%
newdf
# Out:
#           0         1         2         3
# 0  0.548934  0.130458  0.075876  0.593133
# 1  0.480073  0.982473  0.326907  0.430607
# 2  0.252094  0.195783  0.870669  0.695075
# 3  0.656145  0.267462  0.092012  0.145449

# %%
newdf.set_axis(["RANDOM-1","RANDOM-2","RANDOM-3","RANDOM-4"], axis='columns', inplace=True)
# Out:
# <ipython-input-19-3d5ef29ed5b9>:1: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   newdf.set_axis(["RANDOM-1","RANDOM-2","RANDOM-3","RANDOM-4"], axis='columns', inplace=True)

# %%
newdf
# Out:
#    RANDOM-1  RANDOM-2  RANDOM-3  RANDOM-4
# 0  0.548934  0.130458  0.075876  0.593133
# 1  0.480073  0.982473  0.326907  0.430607
# 2  0.252094  0.195783  0.870669  0.695075
# 3  0.656145  0.267462  0.092012  0.145449

# %%
newdf.describe()
# Out:
#        RANDOM-1  RANDOM-2  RANDOM-3  RANDOM-4
# count  4.000000  4.000000  4.000000  4.000000
# mean   0.484312  0.394044  0.341366  0.466066
# std    0.170925  0.396256  0.371050  0.239891
# min    0.252094  0.130458  0.075876  0.145449
# 25%    0.423079  0.179452  0.087978  0.359317
# 50%    0.514504  0.231622  0.209459  0.511870
# 75%    0.575737  0.446215  0.462847  0.618618
# max    0.656145  0.982473  0.870669  0.695075

# %%
newdf.isnull()
# Out:
#    RANDOM-1  RANDOM-2  RANDOM-3  RANDOM-4
# 0     False     False     False     False
# 1     False     False     False     False
# 2     False     False     False     False
# 3     False     False     False     False

# %%
newdf.dtypes
# Out:
# RANDOM-1    float64
# RANDOM-2    float64
# RANDOM-3    float64
# RANDOM-4    float64
# dtype: object

# %%
newdf.loc[:,["RANDOM-2","RANDOM-3"]]
# Out:
#    RANDOM-2  RANDOM-3
# 0  0.130458  0.075876
# 1  0.982473  0.326907
# 2  0.195783  0.870669
# 3  0.267462  0.092012

# %%
newdf.iloc[:,[1,2]]
# Out:
#    RANDOM-2  RANDOM-3
# 0  0.130458  0.075876
# 1  0.982473  0.326907
# 2  0.195783  0.870669
# 3  0.267462  0.092012
